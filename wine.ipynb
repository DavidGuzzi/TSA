# %%
import matplotlib.pyplot as plt
import pandas as pd
path = r"C:\Users\HP\Downloads\wine.csv"
df = pd.read_csv(path, header=None)
df.columns = ['wine']
# Generar el rango de fechas desde enero 1980 a octubre 1991
date_range = pd.date_range(start='1980-01-01', end='1991-10-01', freq='MS')

# Convertir las fechas al formato YYYYMM
df['period'] = date_range.strftime('%Y%m')
df['date'] = pd.to_datetime(date_range)
df.tail()
# Out:
#      wine  period       date
# 137  1892  199106 1991-06-01
# 138  2920  199107 1991-07-01
# 139  2572  199108 1991-08-01
# 140  2617  199109 1991-09-01
# 141  2047  199110 1991-10-01

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
plot_acf(df['wine'], lags = 40)
print()

# %%
df.set_index('period')
df.plot()
# Out:
# <Axes: >
