# %%
pip install fpppy
# Out:
# Collecting fpppy
#   Downloading fpppy-0.0.3-py3-none-any.whl.metadata (300 bytes)
# Requirement already satisfied: matplotlib in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from fpppy) (3.8.4)
# Collecting pre-commit (from fpppy)
#   Downloading pre_commit-4.5.1-py2.py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: pytest in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from fpppy) (8.3.4)
# Collecting pytest-cov (from fpppy)
#   Downloading pytest_cov-7.1.0-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: scikit-learn in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from fpppy) (1.7.2)
# Requirement already satisfied: statsmodels in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from fpppy) (0.14.5)
# Requirement already satisfied: utilsforecast in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from fpppy) (0.2.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->fpppy) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->fpppy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->fpppy) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->fpppy) (1.4.5)
# Requirement already satisfied: numpy>=1.21 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->fpppy) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\appdata\roaming\python\python312\site-packages (from matplotlib->fpppy) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->fpppy) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->fpppy) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\appdata\roaming\python\python312\site-packages (from matplotlib->fpppy) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib->fpppy) (1.16.0)
# Collecting cfgv>=2.0.0 (from pre-commit->fpppy)
#   Downloading cfgv-3.5.0-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting identify>=1.0.0 (from pre-commit->fpppy)
#   Downloading identify-2.6.18-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting nodeenv>=0.11.1 (from pre-commit->fpppy)
#   Downloading nodeenv-1.10.0-py2.py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from pre-commit->fpppy) (6.0.2)
# Collecting virtualenv>=20.10.0 (from pre-commit->fpppy)
#   Downloading virtualenv-21.2.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting distlib<1,>=0.3.7 (from virtualenv>=20.10.0->pre-commit->fpppy)
#   Downloading distlib-0.4.0-py2.py3-none-any.whl.metadata (5.2 kB)
# Collecting filelock<4,>=3.24.2 (from virtualenv>=20.10.0->pre-commit->fpppy)
#   Downloading filelock-3.25.2-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in c:\users\hp\appdata\roaming\python\python312\site-packages (from virtualenv>=20.10.0->pre-commit->fpppy) (4.2.0)
# Collecting python-discovery>=1 (from virtualenv>=20.10.0->pre-commit->fpppy)
#   Downloading python_discovery-1.2.1-py3-none-any.whl.metadata (5.4 kB)
# Collecting platformdirs<5,>=3.9.1 (from virtualenv>=20.10.0->pre-commit->fpppy)
#   Downloading platformdirs-4.9.4-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: colorama in c:\users\hp\appdata\roaming\python\python312\site-packages (from pytest->fpppy) (0.4.6)
# Requirement already satisfied: iniconfig in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from pytest->fpppy) (2.0.0)
# Requirement already satisfied: pluggy<2,>=1.5 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from pytest->fpppy) (1.5.0)
# Collecting coverage>=7.10.6 (from coverage[toml]>=7.10.6->pytest-cov->fpppy)
#   Downloading coverage-7.13.5-cp312-cp312-win_amd64.whl.metadata (8.7 kB)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->fpppy) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->fpppy) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->fpppy) (3.5.0)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from statsmodels->fpppy) (2.2.2)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from statsmodels->fpppy) (0.5.6)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels->fpppy) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels->fpppy) (2024.1)
# Downloading fpppy-0.0.3-py3-none-any.whl (7.1 kB)
# Downloading pre_commit-4.5.1-py2.py3-none-any.whl (226 kB)
# Downloading cfgv-3.5.0-py2.py3-none-any.whl (7.4 kB)
# Downloading identify-2.6.18-py2.py3-none-any.whl (99 kB)
# Downloading nodeenv-1.10.0-py2.py3-none-any.whl (23 kB)
# Downloading virtualenv-21.2.0-py3-none-any.whl (5.8 MB)
#    ---------------------------------------- 0.0/5.8 MB ? eta -:--:--
#    ---------------------------------------- 5.8/5.8 MB 35.7 MB/s eta 0:00:00
# Downloading distlib-0.4.0-py2.py3-none-any.whl (469 kB)
# Downloading filelock-3.25.2-py3-none-any.whl (26 kB)
# Downloading python_discovery-1.2.1-py3-none-any.whl (31 kB)
# Downloading platformdirs-4.9.4-py3-none-any.whl (21 kB)
# Downloading pytest_cov-7.1.0-py3-none-any.whl (22 kB)
# Downloading coverage-7.13.5-cp312-cp312-win_amd64.whl (222 kB)
# Installing collected packages: distlib, platformdirs, nodeenv, identify, filelock, coverage, cfgv, python-discovery, virtualenv, pytest-cov, pre-commit, fpppy
#
#    ----------------------------------------  0/12 [distlib]
#    ----------------------------------------  0/12 [distlib]
#    ----------------------------------------  0/12 [distlib]
#   Attempting uninstall: platformdirs
#    ----------------------------------------  0/12 [distlib]
#     Found existing installation: platformdirs 4.2.0
#    ----------------------------------------  0/12 [distlib]
#     Uninstalling platformdirs-4.2.0:
#    ----------------------------------------  0/12 [distlib]
#       Successfully uninstalled platformdirs-4.2.0
#    ----------------------------------------  0/12 [distlib]
#    --- ------------------------------------  1/12 [platformdirs]
#    --- ------------------------------------  1/12 [platformdirs]
#    ------ ---------------------------------  2/12 [nodeenv]
#    ---------- -----------------------------  3/12 [identify]
#    ------------- --------------------------  4/12 [filelock]
#    ------------- --------------------------  4/12 [filelock]
#    ---------------- -----------------------  5/12 [coverage]
#    ---------------- -----------------------  5/12 [coverage]
#    ---------------- -----------------------  5/12 [coverage]
#    ---------------- -----------------------  5/12 [coverage]
#    ---------------- -----------------------  5/12 [coverage]
#    ---------------- -----------------------  5/12 [coverage]
#    ---------------- -----------------------  5/12 [coverage]
#    ---------------- -----------------------  5/12 [coverage]
#    -------------------- -------------------  6/12 [cfgv]
#    ----------------------- ----------------  7/12 [python-discovery]
#    -------------------------- -------------  8/12 [virtualenv]
#    -------------------------- -------------  8/12 [virtualenv]
#    -------------------------- -------------  8/12 [virtualenv]
#    -------------------------- -------------  8/12 [virtualenv]
#    -------------------------- -------------  8/12 [virtualenv]
#    -------------------------- -------------  8/12 [virtualenv]
#    -------------------------- -------------  8/12 [virtualenv]
#    -------------------------- -------------  8/12 [virtualenv]
#    -------------------------- -------------  8/12 [virtualenv]
#    -------------------------- -------------  8/12 [virtualenv]
#    -------------------------- -------------  8/12 [virtualenv]
#    -------------------------- -------------  8/12 [virtualenv]
#    -------------------------- -------------  8/12 [virtualenv]
#    --------------------------------- ------ 10/12 [pre-commit]
#    --------------------------------- ------ 10/12 [pre-commit]
#    --------------------------------- ------ 10/12 [pre-commit]
#    --------------------------------- ------ 10/12 [pre-commit]
#    --------------------------------- ------ 10/12 [pre-commit]
#    --------------------------------- ------ 10/12 [pre-commit]
#    --------------------------------- ------ 10/12 [pre-commit]
#    --------------------------------- ------ 10/12 [pre-commit]
#    --------------------------------- ------ 10/12 [pre-commit]
#    ---------------------------------------- 12/12 [fpppy]
#
# Successfully installed cfgv-3.5.0 coverage-7.13.5 distlib-0.4.0 filelock-3.25.2 fpppy-0.0.3 identify-2.6.18 nodeenv-1.10.0 platformdirs-4.9.4 pre-commit-4.5.1 pytest-cov-7.1.0 python-discovery-1.2.1 virtualenv-21.2.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import warnings
warnings.filterwarnings(
    "ignore",
    category=UserWarning,
    message=".*FigureCanvasAgg is non-interactive.*"
)
import os
os.environ["NIXTLA_ID_AS_COL"] = "true"
import numpy as np
np.set_printoptions(suppress=True)
np.random.seed(1)
import random
random.seed(1)
import pandas as pd
pd.set_option("max_colwidth", 100)
pd.set_option("display.precision", 3)
from utilsforecast.plotting import plot_series as plot_series_utils
import seaborn as sns
sns.set_style("whitegrid")
import matplotlib.pyplot as plt
plt.style.use("ggplot")
plt.rcParams.update({
    "figure.figsize": (8, 5),
    "figure.dpi": 100,
    "savefig.dpi": 300,
    "figure.constrained_layout.use": True,
    "axes.titlesize": 12,
    "axes.labelsize": 10,
    "xtick.labelsize": 9,
    "ytick.labelsize": 9,
    "legend.fontsize": 9,
    "legend.title_fontsize": 10,
    "grid.alpha": 1.0,
})
import matplotlib as mpl
from cycler import cycler
mpl.rcParams['axes.prop_cycle'] = cycler(color=["#000000", "#000000"])
from fpppy.utils import plot_series

mpl.colormaps.register(
    mpl.colors.ListedColormap(
        ["#000000", "#2f2fff"], name="black_and_blue"),
    force=True,
)
mpl.colormaps.register(
    mpl.colors.ListedColormap(
        ["#000000", "#D55E00"], name="black_and_orange"),
    force=True,
)
mpl.colormaps.register(
    mpl.colors.ListedColormap(
        ["#000000", "#000000"], name="black"),
    force=True,
)
mpl.colormaps.register(
    mpl.colors.ListedColormap(
        ["#000000", "#569CC6", "#D55F03"],
        name='black_and_2color',
    ),
    force=True
)
mpl.colormaps.register(
    mpl.colors.ListedColormap(
        ["#000000", "#D55F03", "#569CC6", "#13A076"],
        name='black_and_3color',
    ),
    force=True
)
mpl.colormaps.register(
    mpl.colors.ListedColormap(
        ["#000000", "#D55F03", "#569CC6", "#13A076", "#CC79A7"],
        name='black_and_4color',
    ),
    force=True
)
mpl.colormaps.register(
    mpl.colors.ListedColormap(
        ["#D55F03", "#569CC6", "#13A076", "#CC79A7"],
        name='r_colors',
    ),
    force=True
)

# %%
from statsforecast import StatsForecast
from statsforecast.models import AutoETS
mpl.rcParams['axes.prop_cycle'] = cycler(color=["#000000", "#2f2fff"])
